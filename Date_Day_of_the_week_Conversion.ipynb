# %%
import matplotlib.pyplot as plt
import requests
from scipy import stats
import pandas as pd

# %%
alien_df = pd.read_csv('../project-1-alien-analysis/alien_region.csv') 
alien_df
# Out:
# /Users/mecross/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        Unnamed: 0          datetime         city state country     shape  \
# 0               0  10/10/1993 22:00       peoria    il      us     light
# 1               1  10/10/1998 13:15        elgin    il      us  cylinder
# 2               2  10/10/2004 15:00  rock island    il      us    sphere
# 3               3  10/10/2010 20:45     sterling    il      us  cylinder
# 4               4  10/10/2012 20:30       marion    il      us     light
# ...           ...               ...          ...   ...     ...       ...
# 60316       60316   6/15/2011 20:19   georgetown    dc      us      disk
# 60317       60317   7/25/2012 21:30   washington    dc      us  changing
# 60318       60318    7/4/2012 21:06   washington    dc      us    sphere
# 60319       60319   8/28/2010 22:06   washington    dc      us  fireball
# 60320       60320    8/9/2012 03:00   washington    dc      us     light
#
#       duration (seconds) duration (hours/min)  \
# 0                      8            8 seconds
# 1                   1800           30 +/- min
# 2                   3600               1 hour
# 3                    600                10min
# 4                    240       2 to 4 minutes
# ...                  ...                  ...
# 60316                  6            6 seconds
# 60317                900        10-15 minutes
# 60318                5.5          5.5 seconds
# 60319                120            2 minutes
# 60320                600           10 minutes
#
#                                                 comments date posted  \
# 0      Light over Peoria&#44 IL that moves slowly&#44...  10/11/2005
# 1      While looking up at sky I noticed a bright lig...   11/1/1998
# 2      The sky was clear  and the objects at times ap...  10/27/2004
# 3      It had rows of white lights with red lights pu...  11/21/2010
# 4      I was leaving my friend&#39s house to go home....  10/30/2012
# ...                                                  ...         ...
# 60316  metallic disk hovering silent in crowded airsp...   6/20/2011
# 60317  3 objects in 15 minutes&#44 2 balls of light m...   8/19/2012
# 60318  Luminous spheres in flight&#44 then suddenly v...    8/5/2012
# 60319  Red flaming object flying low over Washington ...   8/30/2010
# 60320      6 glowing objects fly near roof. (reoccuring)   8/19/2012
#
#         latitude  longitude   Month  Day   Time  Year   region
# 0      40.693611  -89.588889     10   10  22:00  1993  Midwest
# 1      42.037222  -88.281111     10   10  13:15  1998  Midwest
# 2      41.509444  -90.578611     10   10  15:00  2004  Midwest
# 3      41.788611  -89.696111     10   10  20:45  2010  Midwest
# 4      37.730556  -88.933056     10   10  20:30  2012  Midwest
# ...          ...         ...    ...  ...    ...   ...      ...
# 60316  38.904722  -77.062778      6   15  20:19  2011    South
# 60317  38.895000  -77.036667      7   25  21:30  2012    South
# 60318  38.895000  -77.036667      7    4  21:06  2012    South
# 60319  38.895000  -77.036667      8   28  22:06  2010    South
# 60320  38.895000  -77.036667      8    9  03:00  2012    South
#
# [60321 rows x 17 columns]

# %%
#Clean datetime column data 

date_time = pd.to_datetime(alien_df[['Year', 'Month', 'Day']])

alien_df['Datetime_clean'] = date_time

alien_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Sunday"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-43e31e57a284> in <module>
#       1 #Clean datetime column data
#       2
# ----> 3 date_time = pd.to_datetime(alien_df[['Year', 'Month', 'Day']])
#       4
#       5 alien_df['Datetime_clean'] = date_time
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     729             result = arg._constructor(values, index=arg.index, name=arg.name)
#     730     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
# --> 731         result = _assemble_from_unit_mappings(arg, errors, tz)
#     732     elif isinstance(arg, ABCIndexClass):
#     733         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _assemble_from_unit_mappings(arg, errors, tz)
#     855         coerce(arg[unit_rev["year"]]) * 10000
#     856         + coerce(arg[unit_rev["month"]]) * 100
# --> 857         + coerce(arg[unit_rev["day"]])
#     858     )
#     859     try:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in coerce(values)
#     845     def coerce(values):
#     846         # we allow coercion to if errors allows
# --> 847         values = to_numeric(values, errors=errors)
#     848
#     849         # prevent overflow in case of int8 or int16
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     148         try:
#     149             values = lib.maybe_convert_numeric(
# --> 150                 values, set(), coerce_numeric=coerce_numeric
#     151             )
#     152         except (ValueError, TypeError):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Sunday" at position 0

# %%
#Make index column for datetime to date 

alien_df['week_day_index'] = alien_df['Datetime_clean'].dt.dayofweek

alien_df.head()
    
#Assign week_day_index to day of the week 

week_day = {
    0 : 'Monday',
    1 : 'Tuesday',
    2 : 'Wednesday',
    3 : 'Thursday',
    4 : 'Friday',
    5 : 'Saturday',
    6 : 'Sunday',
    }

alien_df['week_day_name'] = ''
for index, row in alien_df.iterrows():
    week_indx = row['week_day_index']
    alien_df.loc[index, 'week_day_name'] = week_day[week_indx]

alien_df.head()
#alien_df['week_day_index'].dtypes
# Out:
#    Unnamed: 0          datetime         city state country     shape  \
# 0           0  10/10/1993 22:00       peoria    il      us     light
# 1           1  10/10/1998 13:15        elgin    il      us  cylinder
# 2           2  10/10/2004 15:00  rock island    il      us    sphere
# 3           3  10/10/2010 20:45     sterling    il      us  cylinder
# 4           4  10/10/2012 20:30       marion    il      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0                  8            8 seconds
# 1               1800           30 +/- min
# 2               3600               1 hour
# 3                600                10min
# 4                240       2 to 4 minutes
#
#                                             comments date posted   latitude  \
# 0  Light over Peoria&#44 IL that moves slowly&#44...  10/11/2005  40.693611
# 1  While looking up at sky I noticed a bright lig...   11/1/1998  42.037222
# 2  The sky was clear  and the objects at times ap...  10/27/2004  41.509444
# 3  It had rows of white lights with red lights pu...  11/21/2010  41.788611
# 4  I was leaving my friend&#39s house to go home....  10/30/2012  37.730556
#
#    longitude   Month        Day   Time  Year   region Datetime_clean  \
# 0  -89.588889     10     Sunday  22:00  1993  Midwest     1993-10-10
# 1  -88.281111     10   Saturday  13:15  1998  Midwest     1998-10-10
# 2  -90.578611     10     Sunday  15:00  2004  Midwest     2004-10-10
# 3  -89.696111     10     Sunday  20:45  2010  Midwest     2010-10-10
# 4  -88.933056     10  Wednesday  20:30  2012  Midwest     2012-10-10
#
#    week_day_index   week_day
# 0               6     Sunday
# 1               5   Saturday
# 2               6     Sunday
# 3               6     Sunday
# 4               2  Wednesday
