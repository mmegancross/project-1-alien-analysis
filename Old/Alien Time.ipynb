# %%
import matplotlib.pyplot as plt
import requests
from scipy import stats
import pandas as pd
import datetime
import numpy as np

# %%
#print csv to df
alien_time_df = pd.read_csv('../project-1-alien-analysis/ufo_dates.csv')
alien_time_df.dropna(inplace = True) 
alien_time_df.head()
# Out:
#            datetime          city state country      shape duration (seconds)  \
# 0  10/10/1993 22:00        peoria    il      us      light                  8
# 1  10/10/1993 23:00      carthage    tn      us      other                 60
# 2  10/10/1994 18:30   burnt hills    ny      us  rectangle                120
# 3  10/10/1994 22:00    pinebergen    ar      us      light                  5
# 6  10/10/1996 03:20  higginsville    mo      us   triangle                  3
#
#   duration (hours/min)                                           comments  \
# 0            8 seconds  Light over Peoria&#44 IL that moves slowly&#44...
# 1      less than 1 min                 1 object with green and red lights
# 2            2 minutes  Giant rectangular craft (resembling an upside-...
# 3            5 seconds  Round&#44 bright&#44 low flying object silentl...
# 6                 3sec  illuminated triangular craft&#44 flying at hig...
#
# ...

# %%
#1st attempt to cut out times
#alien_dates_df = pd.cut(alien_time_df, bins=24)
#
alien_dates_df["binned_hours"] = pd.cut(alien_time_df.datetime.dt.hour, bins=24)
alien_dates_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-2e87bf5e0659> in <module>
#       2 #alien_dates_df = pd.cut(alien_time_df, bins=24)
#       3 #
# ----> 4 alien_dates_df["binned_hours"] = pd.cut(alien_time_df.datetime.dt.hour, bins=24)
#       5 alien_dates_df
#
# ~\.conda\envs\PythonData\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\.conda\envs\PythonData\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# ...

# %%
alien_time_df['Hour'] = ""
for index, row in alien_time_df.iterrows():
        tme = row["Time"]
        hr,mn = tme.split(':')
    
        alien_time_df.loc[index, "Hour"] = hr
    
alien_time_df.head()
# Out:
#            datetime          city state country      shape duration (seconds)  \
# 0  10/10/1993 22:00        peoria    il      us      light                  8
# 1  10/10/1993 23:00      carthage    tn      us      other                 60
# 2  10/10/1994 18:30   burnt hills    ny      us  rectangle                120
# 3  10/10/1994 22:00    pinebergen    ar      us      light                  5
# 6  10/10/1996 03:20  higginsville    mo      us   triangle                  3
#
#   duration (hours/min)                                           comments  \
# 0            8 seconds  Light over Peoria&#44 IL that moves slowly&#44...
# 1      less than 1 min                 1 object with green and red lights
# 2            2 minutes  Giant rectangular craft (resembling an upside-...
# 3            5 seconds  Round&#44 bright&#44 low flying object silentl...
# 6                 3sec  illuminated triangular craft&#44 flying at hig...
#
# ...

# %%
hours_group_df = alien_time_df.groupby('Hour')

# %%
hours_group_df["shape"].count()
# Out:
# Hour
# 00    2829
# 01    2208
# 02    1545
# 03    1368
# 04    1122
# 05    1251
# 06     924
# 07     656
# 08     601
# 09     742
# 10     864
# 11     830
# 12     898
# 13     867
# 14     873
# 15     973
# 16    1121
# 17    1890
# 18    2968
# 19    4564
# 20    6493
# 21    8720
# 22    7950
# 23    5507
# 24     361
# Name: shape, dtype: int64

# %%
test_df=hours_group_df["shape"].count()
test_df.reset_index()
# Out:
#    Hour  shape
# 0    00   2829
# 1    01   2208
# 2    02   1545
# 3    03   1368
# 4    04   1122
# 5    05   1251
# 6    06    924
# 7    07    656
# 8    08    601
# 9    09    742
# 10   10    864
# 11   11    830
# 12   12    898
# 13   13    867
# 14   14    873
# 15   15    973
# 16   16   1121
# 17   17   1890
# 18   18   2968
# 19   19   4564
# 20   20   6493
# 21   21   8720
# 22   22   7950
# 23   23   5507
# 24   24    361

# %%
#frequency = x= number of sigtings per hour
#need to bin down hours
#hours = pd.to_datetime(times=24, format='%H:%M:%S').dt.hour
hours = pd.to_datetime(times_df['1'], format='%H:%M:%S').dt.hour
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-68acf1fc43c5> in <module>
#       2 #need to bin down hours
#       3 #hours = pd.to_datetime(times=24, format='%H:%M:%S').dt.hour
# ----> 4 hours = pd.to_datetime(times_df['1'], format='%H:%M:%S').dt.hour
#       5
#
# TypeError: 'type' object is not subscriptable

# %%
alien_time_df["formatted_time"] = alien_time_df(f"{})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\.conda\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'formatted_time'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-90-1139f8a2db81> in <module>
# ...

# %%
alien_time_df['formatted_time'] = ""
for index, row in alien_time_df.iterrows():
        fmtt = row["Time"]
        hr =row[]
        day
        month
        = tme.split(':')
    
        alien_time_df.loc[index, "Hour"] = hr
    
alien_time_df.head()

# %%
#Sigthing by days of the week
alien_time_df['day_of_week'] = alien_time_df['datetime'].dt.weekday_name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-89-124e05fa3536> in <module>
#       1 #Sigthing by days of the week
# ----> 2 alien_time_df['day_of_week'] = alien_time_df['datetime'].dt.weekday_name
#
# ~\.conda\envs\PythonData\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\.conda\envs\PythonData\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
# ...

# %%
#Sightings by days of the week 

In [13]: friday = pd.Timestamp('2018-01-05')
In [14]: friday.day_name()
Out[14]: 'Friday'
# Add 1 day
In [15]: saturday = friday + pd.Timedelta('1 day')
In [16]: saturday.day_name()
Out[16]: 'Saturday'
# Add 1 business day (Friday --> Monday)
In [17]: monday = friday + pd.offsets.BDay()
In [18]: monday.day_name()
Out[18]: 'Monday'
